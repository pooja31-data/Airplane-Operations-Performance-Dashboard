# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("airline_flight_operations.csv")

# %%
df.head(10)
# Out:
#    flight_id          airline flight_date     origin destination  \
# 0  FLT106794          Vistara  2025-05-11      Delhi     Kolkata
# 1  FLT101782        Air India  2024-04-25    Chennai   Ahmedabad
# 2  FLT108080        Air India  2025-03-24      Delhi   Frankfurt
# 3  FLT104003  British Airways  2025-03-01  Bengaluru     Kolkata
# 4  FLT103000          Vistara  2025-01-14    Kolkata      Mumbai
# 5  FLT102763        Air India  2025-05-14  Hyderabad    Chennai
# 6  FLT103257           IndiGo  2025-01-04  Ahmedabad   Hyderabad
# 7  FLT104867         SpiceJet  2024-05-26      Delhi       Dubai
# 8  FLT104187        Air India  2024-01-14     Mumbai        Doha
# 9  FLT100658         SpiceJet  28/05/2025      Delhi   Hyderabad
#
#   scheduled_departure  actual_departure scheduled_arrival    actual_arrival  \
# 0    2025-05-11 14:59  2025-05-11 15:34  2025-05-11 16:24  2025-05-11 16:59
# 1    2024-04-25 19:33  2024-04-25 19:13  2024-04-25 20:54  2024-04-25 20:29
# ...

# %%
df.isnull().sum()
# Out:
# flight_id                 8
# airline                  45
# flight_date              35
# origin                   29
# destination              31
# scheduled_departure      25
# actual_departure         30
# scheduled_arrival         0
# actual_arrival            0
# departure_delay           0
# arrival_delay             0
# cancelled                 0
# cancellation_reason    8114
# flight_distance_km        0
# aircraft_type            25
# passengers               35
# baggage_count             0
# weather_condition        40
# airport_congestion        0
# ticket_price             30
# status                    0
# dtype: int64

# %%
df=df.dropna(subset=["flight_id"])

# %%
df.shape
# Out:
# (8592, 21)

# %%
df.duplicated().sum()
# Out:
# np.int64(100)

# %%
df.drop_duplicates()
# Out:
#       flight_id          airline flight_date     origin destination  \
# 0     FLT106794          Vistara  2025-05-11      Delhi     Kolkata
# 1     FLT101782        Air India  2024-04-25    Chennai   Ahmedabad
# 2     FLT108080        Air India  2025-03-24      Delhi   Frankfurt
# 3     FLT104003  British Airways  2025-03-01  Bengaluru     Kolkata
# 4     FLT103000          Vistara  2025-01-14    Kolkata      Mumbai
# ...         ...              ...         ...        ...         ...
# 8595  FLT107192          Vistara  2025-04-17       Pune   Hyderabad
# 8596  FLT104848          Vistara  2024-04-03       Pune   Ahmedabad
# 8597  FLT103912        Air India  2024-05-19  Bengaluru     Chennai
# 8598  FLT103768         Emirates  2024-11-14    Kolkata   Singapore
# 8599  FLT105139        Lufthansa  2025-04-23      Delhi   Singapore
#
#      scheduled_departure  actual_departure scheduled_arrival  \
# 0       2025-05-11 14:59  2025-05-11 15:34  2025-05-11 16:24
# ...

# %%
df["airline"].unique()
# Out:
# array(['Vistara', 'Air India', 'British Airways', 'IndiGo', 'SpiceJet',
#        'Akasa Air', 'Lufthansa', 'Qatar Airways', 'Akasa Air ',
#        'Singapore Airlines', 'spicejet', 'Emirates', nan, 'SPICEJET',
#        'Vistara ', 'IndiGo ', 'vistara', 'AirIndia', 'air india',
#        ' SpiceJet ', 'AKASA AIR', 'akasa air', 'Emirates ',
#        'British Airways ', 'Qatar Airways ', ' Air India ',
#        'Singapore Airlines ', 'Air India ', 'AIR INDIA', 'INDIGO',
#        'indigo', 'Lufthansa ', 'AkasaAir', 'SpiceJet ', 'VISTARA',
#        ' Indigo', 'Spice Jet'], dtype=object)

# %%
df["airline"]=(df["airline"].str.strip().str.title())

# %%
df["airline"].unique()
# Out:
# array(['Vistara', 'Air India', 'British Airways', 'Indigo', 'Spicejet',
#        'Akasa Air', 'Lufthansa', 'Qatar Airways', 'Singapore Airlines',
#        'Emirates', nan, 'Airindia', 'Akasaair', 'Spice Jet'], dtype=object)

# %%
df["airline"]=
